# %%
from json import load
import os

# %%
jd_loc = r'json'
cd_loc = r'csv'

cars = []
fishs = []
houses = []
trees = []
bicycles = []
guitars = []
pencils = []
clocks = []

items = {
    'car': cars,
    'fish': fishs,
    'house': houses,
    'tree': trees,
    'bicycle': bicycles,
    'guitar': guitars,
    'pencil': pencils,
    'clock': clocks,
}

# %%
def get_n_paths(shape):
    return len(shape)

def get_n_points(shape):
    return sum( len(path) for path in shape )

info = {
    'n_paths': get_n_paths,
    'n_points' : get_n_points,
}

# %%
def turn_jd_to_cd(jf_loc):
    with open(jf_loc, 'r') as file:
        jf = load(file)
        for item, l in items.items():
            data = [] 
            shape = jf.get('drawings').get(item)
            for _, info_func in info.items():
                data.append(info_func(shape))
            l.extend(data)
            #l.append(item) # class

# %%
jf_names = os.listdir(jd_loc)[:]
for n, jf_name in enumerate(jf_names):
    jf_loc = os.path.join(jd_loc, jf_name)
    print(f'{n+1}/{len(jf_names)} : {jf_name}', end='\r')
    turn_jd_to_cd(jf_loc)
# Out:
# 102/716 : 1663864656131.json
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\Users\Aymane\Desktop\Projects\drawing_app\data\turn_json_to_csv.ipynb Cell 5 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/Aymane/Desktop/Projects/drawing_app/data/turn_json_to_csv.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> jf_loc = os.path.join(jd_loc, jf_name)
#       <a href='vscode-notebook-cell:/c%3A/Users/Aymane/Desktop/Projects/drawing_app/data/turn_json_to_csv.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> print(f'{n+1}/{len(jf_names)} : {jf_name}', end='\r')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Aymane/Desktop/Projects/drawing_app/data/turn_json_to_csv.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> turn_jd_to_cd(jf_loc)
#
# c:\Users\Aymane\Desktop\Projects\drawing_app\data\turn_json_to_csv.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Aymane/Desktop/Projects/drawing_app/data/turn_json_to_csv.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> def turn_jd_to_cd(jf_loc):
#       <a href='vscode-notebook-cell:/c%3A/Users/Aymane/Desktop/Projects/drawing_app/data/turn_json_to_csv.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a>     with open(jf_loc, 'r') as file:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Aymane/Desktop/Projects/drawing_app/data/turn_json_to_csv.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a>         jf = load(file)
#       <a href='vscode-notebook-cell:/c%3A/Users/Aymane/Desktop/Projects/drawing_app/data/turn_json_to_csv.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a>         for item, l in items.items():
#       <a href='vscode-notebook-cell:/c%3A/Users/Aymane/Desktop/Projects/drawing_app/data/turn_json_to_csv.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a>             data = []
#
# File c:\Users\Aymane\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File c:\Users\Aymane\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 38: character maps to <undefined>

# %%
cars
# Out:
# [5,
#  883,
#  7,
#  715,
#  7,
#  658,
#  19,
#  799,
#  1,
#  255,
#  18,
#  748,
#  7,
#  1869,
#  7,
#  726,
#  8,
#  596,
#  4,
#  516,
#  5,
#  680,
#  15,
#  1355,
#  17,
#  885,
#  8,
#  1352,
#  6,
#  520,
#  8,
#  425,
#  26,
#  1053,
#  8,
#  759,
#  6,
#  469,
#  11,
#  1523,
#  12,
#  616,
#  25,
#  2078,
#  7,
#  463,
#  5,
#  818,
#  14,
#  1122,
#  11,
#  1096,
#  14,
#  1176,
#  2,
#  384,
#  16,
#  789,
#  8,
#  735,
#  5,
#  928,
#  1,
#  358,
#  5,
#  459,
#  14,
#  812,
#  40,
#  1920,
#  7,
#  560,
#  38,
#  2032,
#  7,
#  807,
#  21,
#  806,
#  12,
#  511,
#  7,
#  732,
#  6,
#  909,
#  42,
#  6522,
#  5,
#  325,
#  16,
#  1025,
#  19,
#  624,
#  8,
#  123,
#  6,
#  214,
#  1,
#  277,
#  5,
#  878,
#  16,
#  675,
#  3,
#  730,
#  11,
#  860,
#  17,
#  1596,
#  4,
#  134,
#  5,
#  773,
#  18,
#  779,
#  23,
#  2203,
#  5,
#  1006,
#  16,
#  1547,
#  11,
#  962,
#  14,
#  3085,
#  8,
#  547,
#  20,
#  828,
#  25,
#  518,
#  15,
#  506,
#  9,
#  648,
#  3,
#  683,
#  12,
#  645,
#  34,
#  1126,
#  4,
#  185,
#  8,
#  404,
#  8,
#  431,
#  5,
#  1070,
#  6,
#  766,
#  3,
#  352,
#  11,
#  468,
#  10,
#  518,
#  6,
#  353,
#  12,
#  505,
#  48,
#  1876,
#  25,
#  593,
#  8,
#  265,
#  9,
#  577,
#  10,
#  842,
#  5,
#  695,
#  4,
#  197,
#  14,
#  1041,
#  21,
#  1177,
#  8,
#  404,
#  32,
#  1379,
#  8,
#  453,
#  14,
#  946,
#  11,
#  651,
#  23,
#  2330,
#  27,
#  1566,
#  7,
#  1410,
#  11,
#  1069,
#  21,
#  589,
#  5,
#  811,
#  2,
#  80,
#  5,
#  883,
#  7,
#  715,
#  5,
#  883,
#  7,
#  715]
